# %%
from x_utils import group_and_aggregate
import pandas as pd

# %%
# Charger les deux fichiers CSV
df_2009_2010 = pd.read_csv('data/silver_2009_2010_cleaned.csv')
df_2011 = pd.read_csv('data/silver_2011.csv')

# %%
df_2009_2010 = group_and_aggregate(df_2009_2010)

# %%
df_2009_2010[df_2009_2010['∃_items'] != df_2009_2010.Frequency]
# Out:
#              Recency  Frequency  Monetary  Quantity    Ø_Price  ∃_items  \
# Customer ID
# 12346.0          725         14     51.76        54  10.498182       28
# 12347.0          403          2   1323.32       828   2.295070       70
# 12348.0          437          2   1114.96      1627   1.729459       21
# 12349.0          735          4   2646.99       988   8.406449       92
# 12352.0          392          2    343.80       188   3.033333       18
# ...              ...        ...       ...       ...        ...      ...
# 18283.0          657          6    619.37       322   2.199401      158
# 18284.0          431          2    436.68       493   4.003103       28
# 18285.0          660          1    427.00       145   8.350000       12
# 18286.0          723          3   1188.43       592   4.379286       67
# 18287.0          737          5   2340.61      1425   2.841163       78
#
#              %_Cancelled  Ø_Qty  Ø_InvoiceQty  Average_Price  Ø_basket  \
# Customer ID
# ...

# %%
df_2009_2010
# Out:
#              Recency  Frequency  Monetary  Quantity    Ø_Price  ∃_items  \
# Customer ID
# 12346.0          725         14     51.76        54  10.498182       28
# 12347.0          403          2   1323.32       828   2.295070       70
# 12348.0          437          2   1114.96      1627   1.729459       21
# 12349.0          735          4   2646.99       988   8.406449       92
# 12352.0          392          2    343.80       188   3.033333       18
# ...              ...        ...       ...       ...        ...      ...
# 18283.0          657          6    619.37       322   2.199401      158
# 18284.0          431          2    436.68       493   4.003103       28
# 18285.0          660          1    427.00       145   8.350000       12
# 18286.0          723          3   1188.43       592   4.379286       67
# 18287.0          737          5   2340.61      1425   2.841163       78
#
#              %_Cancelled  Ø_Qty  Ø_InvoiceQty  Average_Price  Ø_basket  \
# Customer ID
# ...

# %%
df_2009_2010.to_csv('data/gold_2009_2010.csv', index=False)
